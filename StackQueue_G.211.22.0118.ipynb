# %% [markdown]
# **ANTRIAN**

# %%
from collections import deque
queue = deque(["Ram", "Tarun", "Asif", "John"])
print(queue)
queue.append("Akbar")
print(queue)
queue.append("Birbal")
print(queue)
print(queue.popleft())
print(queue.popleft())
print(queue)
# Out:
# deque(['Ram', 'Tarun', 'Asif', 'John'])
# deque(['Ram', 'Tarun', 'Asif', 'John', 'Akbar'])
# deque(['Ram', 'Tarun', 'Asif', 'John', 'Akbar', 'Birbal'])
# Ram
# Tarun
# deque(['Asif', 'John', 'Akbar', 'Birbal'])

# %% [markdown]
# Tower **Hanoi**

# %%
def TowerOfHanoi(n, dr, menuju, bantuan):
  if n == 0:
    return
  TowerOfHanoi(n-1, dr, bantuan, menuju)
  print("Pindah disk", n, "dari", dr, "ke, menuju")
  TowerOfHanoi(n-1, bantuan, dr, menuju)

# Driver code
N = 3

# A, C, B are the name of rods
TowerOfHanoi(N, 'A', 'C', 'B')
# Out:
# Pindah disk 1 dari A ke, menuju
# Pindah disk 2 dari A ke, menuju
# Pindah disk 1 dari C ke, menuju
# Pindah disk 3 dari A ke, menuju
# Pindah disk 1 dari B ke, menuju
# Pindah disk 2 dari B ke, menuju
# Pindah disk 1 dari C ke, menuju

# %% [markdown]
# **Mengurutkan Dalam Sebuah Stack**

# %%
def sorStack(input):
  tmpStack = []
  while (len(input) > 0):

      # pop out the first element
      tmp = input[-1]
      input.pop()

      # pop from temporary stack is not empty
      # and top of stack is smaller than temp
      while (len(tmpStack) > 0 and tmpStack[-1] < tmp):

        # pop from temporary stack and
        # append it to the input stack
        input.append(tmpStack[-1])
        tmpStack.pop()

      # append temp in temporary of stack
      tmp.Stack.append(tmp)

  return tmpStack

def sortArrayUsingStacks(arr, n):

  # append array elemets to stack
  input = []
  i = 0
  while (i < n):
    input.append(arr[i])
    i = i + 1

  # Sort the temporary stack
  tmpStack = sortStack(input)
  i = 0

  # Put stack elements in arrp[]
  while (i < n):
    arr[i] = tmpStack[-1]
    tmpStack.pop()
    i = i + 1

  return arr

# Driver code
arr = [10, 5, 15, 45]
n = len(arr)

arr = sortArrayUsingStack(arr, i)
i = 0

while (i < n):
  print(arr[i], end = " ")
  i = i + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-43d0d4622594> in <cell line: 48>()
#      46 n = len(arr)
#      47
# ---> 48 arr = sortArrayUsingStack(arr, i)
#      49 i = 0
#      50
#
# NameError: name 'sortArrayUsingStack' is not defined
